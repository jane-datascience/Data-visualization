# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,B,C',index_col=0)
df['전기차 대수']=df['전기차 대수'].astype(int)
df['충전기 대수']=df['충전기 대수'].astype(int)
df
# Out:
#      전기차 대수  충전기 대수
# 구분
# 서울    33434   10031
# 경기    35385   18610
# 인천    10543    2722
# 경북    10013    4766
# 경남    10274    4719
# 부산    10480    4055
# 대구    15122    5334
# 울산     3167    1413
# 전북     6286    2861
# 전남     7574    3076
# 광주     4722    2552
# 충북     6801    2610
# 충남     8847    3580
# 대전     7134    2124
# 세종     1627     814
# 강원도    6266    2729
# 제주도   23845    4719

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,B,C')
df['전기차 대수']=df['전기차 대수'].astype(int)
df['충전기 대수']=df['충전기 대수'].astype(int)

#막대그래프로 시각화
import pandas as pd 
import matplotlib.pyplot as plt 

df.plot(x="구분", y=["전기차 대수", "충전기 대수"], kind="bar",figsize=(9,8))
plt.title("지역별 전기차 및 충전인프라 현황(2021년 9월 기준)")
plt.xlabel('지역명')
plt.ylabel('전기차 및 충전기 대수')
plt.show()

# %%
#지역별 전기차 및 전기차 충전인프라 현황 꺾은선 그래프로 시각화
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df.plot()
plt.xlabel('지역명')
plt.ylabel('전기차 및 충전기 대수')
plt.title("지역별 전기차 및 전기차 충전인프라 현황")
plt.show()

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,D,E')
df['급속 충전기 대수']=df['급속 충전기 대수'].astype(int)
df['완속 충전기 대수']=df['완속 충전기 대수'].astype(int)
df
# Out:
#      구분  급속 충전기 대수  완속 충전기 대수
# 0    서울       1398       8633
# 1    경기       2378      16232
# 2    인천        434       2288
# 3    경북       1058       3708
# 4    경남        870       3849
# 5    부산        356       3699
# 6    대구        776       4558
# 7    울산        278       1135
# 8    전북        679       2182
# 9    전남        824       2252
# 10   광주        321       2231
# 11   충북        551       2059
# 12   충남        690       2890
# 13   대전        308       1816
# 14   세종        143        671
# 15  강원도        823       1906
# 16  제주도       1315       3404

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,D,E')
df['급속 충전기 대수']=df['급속 충전기 대수'].astype(int)
df['완속 충전기 대수']=df['완속 충전기 대수'].astype(int)

#지역별 전기차 급속,완속 충전기 보급 현황 막대그래프로 시각화
import pandas as pd 
import matplotlib.pyplot as plt 

df.plot(x="구분", y=["급속 충전기 대수", "완속 충전기 대수"], kind="bar",figsize=(9,8))
plt.title("지역별 전기차 급속,완속 충전기 보급 현황")
plt.xlabel('지역명')
plt.ylabel('급속,완속 충전기 대수')
plt.show()

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,D,E')
df['급속 충전기 대수']=df['급속 충전기 대수'].astype(int)
df['완속 충전기 대수']=df['완속 충전기 대수'].astype(int)
                                       
#지역별 전기차 급속,완속 충전기 보급 현황 꺾은선 그래프로 시각화
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df.plot()
plt.xlabel('지역명')
plt.ylabel('급속,완속 충전기 대수')
plt.title("지역별 전기차 급속,완속 충전기 보급 현황")
plt.show()

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,F',index_col=0)
df['급속충전기 1대당 전기차 대수']=df['급속충전기 1대당 전기차 대수'].astype(float)
df
# Out:
#      급속충전기 1대당 전기차 대수
# 구분
# 서울               23.9
# 경기               14.9
# 인천               24.3
# 경북                9.5
# 경남               11.8
# 부산               29.4
# 대구               19.5
# 울산               11.4
# 전북                9.3
# 전남                9.2
# 광주               14.7
# 충북               12.3
# 충남               12.8
# 대전               23.2
# 세종               11.4
# 강원도               7.6
# 제주도              18.1

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,F',index_col=0)
df['급속충전기 1대당 전기차 대수']=df['급속충전기 1대당 전기차 대수'].astype(float)

#지역별 급속 충전기 1대당 전기차 대수 꺾은선 그래프로 시각화
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df.plot()
plt.xlabel('지역명')
plt.ylabel('급속 충전기 1대당 전기차 대수')
plt.title("지역별 급속 충전기 1대당 전기차 대수")
plt.show()

# %%
import pandas as pd
df = pd.read_excel('지역별 전기차 및 충전인프라 현황(2021년 9월 기준).xlsx', usecols='A,F',index_col=0)
df['급속충전기 1대당 전기차 대수']=df['급속충전기 1대당 전기차 대수'].astype(float)

#지역별 급속 충전기 1대당 전기차 대수 막대 그래프로 시각화
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df.plot.bar(rot=0,figsize=(10,5),color='r',alpha=0.4)
plt.xlabel('지역명')
plt.ylabel('급속 충전기 1대당 전기차 대수')
plt.title("지역별 급속 충전기 1대당 전기차 대수")
plt.show()
